# %%
from dlib_face_cluster import face_clustering

pred_lan_path = "shape_predictor_5_face_landmarks.dat"
face_rec_path = "dlib_face_recognition_resnet_model_v1.dat"

input_folder = "D://programming//bram_playground//faceswap//data//photos//an//src//RAW//as1"
output_folder = "D://programming//bram_playground//faceswap//data//photos//an//src//RAW//as1-clustered"

#linux
input_folder = "//media//bram//data//programming//bram_playground//f//data//an-th//th"
output_folder = "//media//bram//data//programming//bram_playground//f//data//an-th//th-clutered"


face_clustering(pred_lan_path, face_rec_path, input_folder, output_folder)
# Out:
# files left :1430
# files left :1429
# files left :1428
# files left :1427
# files left :1426
# files left :1425
# files left :1424
# files left :1423
# files left :1422
# files left :1421
# files left :1420
# files left :1419
# files left :1418
# files left :1417
# files left :1416
# files left :1415
# files left :1414
# files left :1413
# files left :1412
# files left :1411
# files left :1410
# files left :1409
# files left :1408
# files left :1407
# files left :1406
# files left :1405
# files left :1404
# files left :1403
# files left :1402
# files left :1401
# files left :1400
# files left :1399
# files left :1398
# files left :1397
# files left :1396
# files left :1395
# files left :1394
# files left :1393
# files left :1392
# files left :1391
# files left :1390
# files left :1389
# files left :1388
# files left :1387
# files left :1386
# files left :1385
# files left :1384
# files left :1383
# files left :1382
# files left :1381
# files left :1380
# files left :1379
# ...
